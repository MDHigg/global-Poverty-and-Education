# %% [markdown]
# # Describing the Clean Datasets
#
# ## 01 Import libraries
# ## 02 Import Data
# ## 03 Describe the dataframes

# %%
import os
import numpy as np
import pandas as pd

# Set display options:
# No limit on rows and columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# 2dp floating point
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# ## 02 Import data

# %%
# import dataframe

pathData = r'C:\Users\Michael\Desktop\Career Foundry\02 Data Immersion Course\06 Advanced Analytics and Dashboard Design\00 Data'
econ = pd.read_csv(os.path.join(pathData, 'World Bank Cleaned', 'econgrowth_clean.csv'))
educ = pd.read_csv(os.path.join(pathData, 'World Bank Cleaned', 'education_clean.csv'))
pove = pd.read_csv(os.path.join(pathData, 'World Bank Cleaned', 'poverty_clean.csv'))

# %% [markdown]
# ## 03 Describe Data

# %%
econ.describe().to_clipboard()
econ.describe()
# Out:
#        Unnamed: 0    Year  GDP per capita (constant 2015 US$)  \
# count     6630.00 6630.00                             6573.00
# mean      3314.50 2008.63                            13724.52
# std       1914.06    7.46                            20883.65
# min          0.00 1996.00                              234.71
# 25%       1657.25 2002.00                             1679.70
# 50%       3314.50 2009.00                             4961.17
# 75%       4971.75 2015.00                            16860.57
# max       6629.00 2021.00                           204190.97
#
#        GDP per capita growth (annual %)  GNI per capita (constant 2015 US$)  \
# count                           6598.00                             5110.00
# mean                               2.08                            12205.75
# std                                5.53                            17653.18
# min                              -55.09                              229.40
# 25%                                0.16                             1566.38
# 50%                                2.19                             4454.24
# 75%                                4.26                            14111.75
# max                              140.48                           138201.22
#
#        GNI per capita growth (annual %)
# count                           4840.00
# mean                               2.18
# std                                4.93
# min                              -61.95
# 25%                                0.17
# 50%                                2.29
# 75%                                4.46
# max                               46.26

# %%
educ.describe().to_clipboard()
educ.describe()
# Out:
#          Year  Adolescents out of school (% of lower secondary school age)  \
# count 6337.00                                            3775.00
# mean  2008.60                                              14.82
# std      7.47                                              17.64
# min   1996.00                                               0.00
# 25%   2002.00                                               2.13
# 50%   2009.00                                               8.08
# 75%   2015.00                                              19.73
# max   2021.00                                              88.65
#
#        Adolescents out of school, female (% of female lower secondary school age)  \
# count                                            3339.00
# mean                                               16.84
# std                                                19.75
# min                                                 0.04
# 25%                                                 2.91
# 50%                                                 8.89
# 75%                                                22.90
# max                                                91.41
#
#        Adolescents out of school, male (% of male lower secondary school age)  \
# count                                            3339.00
# mean                                               15.35
# std                                                16.56
# min                                                 0.04
# 25%                                                 3.12
# 50%                                                 9.51
# 75%                                                21.66
# max                                                86.19
#
#        Children out of school (% of primary school age)  \
# count                                           4447.00
# mean                                              10.34
# std                                               14.27
# min                                                0.00
# 25%                                                1.27
# 50%                                                4.46
# 75%                                               12.40
# max                                               76.55
#
#        Children out of school, female (% of female primary school age)  \
# count                                            3762.00
# mean                                               12.57
# std                                                16.04
# min                                                 0.01
# 25%                                                 1.99
# 50%                                                 5.98
# 75%                                                14.99
# max                                                81.85
#
#        Children out of school, male (% of male primary school age)  \
# count                                            3762.00
# mean                                               11.17
# std                                                13.55
# min                                                 0.02
# 25%                                                 2.15
# 50%                                                 5.93
# 75%                                                13.63
# max                                                71.43
#
#        Government expenditure on education, total (% of GDP)  \
# count                                            5109.00
# mean                                                4.40
# std                                                 2.14
# min                                                 0.00
# 25%                                                 3.00
# 50%                                                 4.14
# 75%                                                 5.37
# max                                                15.59
#
#        Primary completion rate, female (% of relevant age group)  \
# count                                            5504.00
# mean                                               84.74
# std                                                21.47
# min                                                 7.16
# 25%                                                73.26
# 50%                                                93.17
# 75%                                                98.90
# max                                               142.93
#
#        Primary completion rate, male (% of relevant age group)  \
# count                                            5504.00
# mean                                               86.66
# std                                                18.38
# min                                                13.82
# 25%                                                76.23
# 50%                                                92.78
# 75%                                                99.02
# max                                               177.63
#
#        Primary completion rate, total (% of relevant age group)  \
# count                                            5581.00
# mean                                               85.78
# std                                                19.64
# min                                                13.71
# 25%                                                74.59
# 50%                                                93.17
# 75%                                                98.85
# max                                               152.81
#
#        School enrollment, primary (% net)  \
# count                             5305.00
# mean                                87.40
# std                                 13.13
# min                                 24.03
# 25%                                 84.51
# 50%                                 92.29
# 75%                                 95.79
# max                                100.00
#
#        School enrollment, primary, female (% net)  \
# count                                     4563.00
# mean                                        84.96
# std                                         14.98
# min                                         18.57
# 25%                                         81.29
# 50%                                         90.25
# 75%                                         95.00
# max                                         99.99
#
#        School enrollment, primary, male (% net)  \
# count                                   4563.00
# mean                                      86.89
# std                                       12.41
# min                                       29.31
# 25%                                       83.34
# 50%                                       91.18
# 75%                                       95.27
# max                                       99.99
#
#        School enrollment, secondary (% net)  \
# count                               4706.00
# mean                                  65.95
# std                                   24.71
# min                                    2.77
# 25%                                   46.58
# 50%                                   72.77
# 75%                                   87.23
# max                                   99.91
#
#        School enrollment, secondary, female (% net)  \
# count                                       4683.00
# mean                                          66.04
# std                                           25.94
# min                                            2.27
# 25%                                           46.64
# 50%                                           74.72
# 75%                                           88.04
# max                                          100.00
#
#        School enrollment, secondary, male (% net)
# count                                     4683.00
# mean                                        65.67
# std                                         23.73
# min                                          3.28
# 25%                                         47.07
# 50%                                         71.43
# 75%                                         86.42
# max                                        100.00

# %%
pove.describe().to_clipboard()
pove.describe()
# Out:
#          Year  Gini index  \
# count 3882.00     3384.00
# mean  2008.96       38.75
# std      7.03        8.35
# min   1996.00       23.20
# 25%   2003.00       32.60
# 50%   2009.00       37.50
# 75%   2015.00       43.70
# max   2021.00       65.80
#
#        Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)  \
# count                                            3749.00
# mean                                               16.24
# std                                                20.94
# min                                                 0.00
# 25%                                                 0.60
# 50%                                                 5.40
# 75%                                                26.90
# max                                                91.50
#
#        Poverty headcount ratio at $3.65 a day (2017 PPP) (% of population)  \
# count                                            3749.00
# mean                                               30.28
# std                                                29.94
# min                                                 0.00
# 25%                                                 1.70
# 50%                                                19.40
# 75%                                                56.90
# max                                                97.60
#
#        Poverty headcount ratio at $6.85 a day (2017 PPP) (% of population)  \
# count                                            3749.00
# mean                                               48.70
# std                                                35.53
# min                                                 0.00
# 25%                                                10.00
# 50%                                                50.50
# 75%                                                85.00
# max                                                99.70
#
#        Poverty headcount ratio at national poverty lines (% of population)
# count                                            2225.00
# mean                                               29.51
# std                                                16.19
# min                                                 0.00
# 25%                                                17.00
# 50%                                                25.13
# 75%                                                40.20
# max                                                82.30
